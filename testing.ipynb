# %%
import numpy as np
import random
import json
from tqdm.notebook import tqdm
from nltk.stem import PorterStemmer
from sentence_transformers import SentenceTransformer

# %%
with open('word_lists/codenames.txt') as f:
    original_words = np.array(f.read().splitlines())
with open('word_lists/duet.txt') as f:
    duet_words = np.array(f.read().splitlines())
with open('word_lists/deep_undercover.txt') as f:
    undercover_words = np.array(f.read().splitlines())

WORD_POOL = duet_words
GRID_SIZE = 5

def generate_grids(word_pool = WORD_POOL):
    word_grid = list(np.random.choice(word_pool, GRID_SIZE**2, replace=False).reshape([GRID_SIZE,GRID_SIZE]))
    key_cards = list(zip(
        ['A','B','B','B','B','B','F','F','F','F','F','F','F','F','F','B','A','B','B','B','B','B','B','B','A'], 
        ['F','F','F','F','F','F','F','F','F','B','B','B','B','B','A','A','A','B','B','B','B','B','B','B','B']
    ))
    random.shuffle(key_cards)
    key_grid_player, key_grid_model = zip(*key_cards)
    key_grid_player = list(np.reshape(key_grid_player, [GRID_SIZE,GRID_SIZE]))
    key_grid_model = list(np.reshape(key_grid_model, [GRID_SIZE,GRID_SIZE]))
    return word_grid, key_grid_player, key_grid_model

word_grid, key_grid_player, key_grid_model = generate_grids()

# %%
word_grid
# Out:
# [array(['GENIE', 'PAINT', 'LIP', 'MILL', 'LACE'], dtype='<U11'),
#  array(['RUBBER', 'BOIL', 'TEAM', 'SPURS', 'FUEL'], dtype='<U11'),
#  array(['CAPTAIN', 'JUDGE', 'DISK', 'BARBECUE', 'RAIL'], dtype='<U11'),
#  array(['COACH', 'THUNDER', 'CLOUD', 'MINUTE', 'RAZOR'], dtype='<U11'),
#  array(['ANTHEM', 'CHRISTMAS', 'BENCH', 'FOG', 'ARMOR'], dtype='<U11')]

# %%
key_grid_player
# Out:
# [array(['F', 'B', 'A', 'F', 'F'], dtype='<U1'),
#  array(['B', 'B', 'B', 'F', 'B'], dtype='<U1'),
#  array(['F', 'A', 'B', 'F', 'B'], dtype='<U1'),
#  array(['B', 'B', 'B', 'F', 'B'], dtype='<U1'),
#  array(['A', 'F', 'B', 'F', 'B'], dtype='<U1')]

# %%
key_grid_model
# Out:
# [array(['A', 'F', 'F', 'F', 'F'], dtype='<U1'),
#  array(['B', 'F', 'B', 'F', 'F'], dtype='<U1'),
#  array(['B', 'A', 'F', 'B', 'B'], dtype='<U1'),
#  array(['A', 'B', 'B', 'B', 'B'], dtype='<U1'),
#  array(['B', 'B', 'F', 'B', 'B'], dtype='<U1')]

# %%
def get_word_groups(word_grid, key_grid):
    word_groups = {}
    for i in range(len(key_grid)):
        for j in range(len(key_grid[i])):
            key = key_grid[i][j]
            word = word_grid[i][j]
            
            if key in word_groups:
                word_groups[key].append(word)
            else:
                word_groups[key] = [word]
    
    return word_groups

def filter_dict_by_stemmed_keys(data_dict, word_list):
    stemmer = PorterStemmer()

    # Stem all words in the list
    stemmed_words = {stemmer.stem(word) for word in word_list}

    def should_remove(key):
        """Check if a given key should be removed based on the conditions."""
        stemmed_key = stemmer.stem(key)
        for word in stemmed_words:
            if stemmed_key == word or word in stemmed_key or stemmed_key in word:
                return True
        return False

    # Filter dictionary based on the should_remove condition
    filtered_dict = {key: value for key, value in data_dict.items() if not should_remove(key)}

    return filtered_dict

# %%
def normalize(v):
    """Return the unit vector of v."""
    norm = np.linalg.norm(v)
    return v if norm == 0 else v / norm

def cosine_similarity(a, b):
    """Compute cosine similarity between two vectors."""
    return np.dot(a, b)

def nearest_neighbor(v_star, candidate_embs):
    """
    Given an ideal clue vector v_star and a dictionary mapping candidate clue words
    to their precomputed embeddings, return the candidate with the highest cosine similarity.
    """
    best_word = None
    best_sim = -np.inf
    for word, emb in candidate_embs.items():
        sim = cosine_similarity(v_star, emb)
        if sim > best_sim:
            best_sim = sim
            best_word = word
    return best_word

def find_best_cluster(
    friend_words, 
    non_friend_words,
    friend_embs,  
    non_friend_embs, 
    candidate_embs,
    target_N=3, 
    penalty_coeff=0.2,
    verbose=True
):
    """
    ...
    """
    best_score = -np.inf
    best_cluster = None
    best_N = None
    best_v_star = None

    # Loop over all possible cluster sizes.
    for N in range(1, len(friend_words) + 1):
        if verbose:
            print(f"N = {N}")
            print()
        # Try every friendly word as a potential seed for the cluster.
        for seed in friend_words:
            if verbose:
                print(f"Cluster seed = \"{seed}\"")
            cluster = [seed]
            remaining = set(friend_words) - {seed}
            # Greedily grow the cluster until it has N words.
            while len(cluster) < N and remaining:
                best_candidate = None
                best_avg_sim = -np.inf
                for candidate in remaining:
                    # Compute average cosine similarity between candidate and the current cluster.
                    sim_sum = sum(cosine_similarity(friend_embs[candidate], friend_embs[w])
                                  for w in cluster)
                    avg_sim = sim_sum / len(cluster)
                    if avg_sim > best_avg_sim:
                        best_avg_sim = avg_sim
                        best_candidate = candidate
                if best_candidate is not None:
                    cluster.append(best_candidate)
                    remaining.remove(best_candidate)
                else:
                    break
            # Only consider complete clusters of size N.
            if len(cluster) != N:
                continue
            # Compute the centroid of the cluster.
            centroid = normalize(sum(friend_embs[w] for w in cluster))
            # Calculate the minimum similarity from the cluster words to the centroid.
            friend_sims = [cosine_similarity(centroid, friend_embs[w]) for w in cluster]
            min_friend_sim = min(friend_sims)
            # Calculate the maximum similarity from any non-friendly word to the centroid.
            non_friend_sims = [cosine_similarity(centroid, non_friend_embs[w]) for w in non_friend_words]
            max_non_friend_sim = max(non_friend_sims) if non_friend_sims else -np.inf
            # Define a margin that measures the separation.
            margin = min_friend_sim - max_non_friend_sim
            # Optionally, you could add a bonus for larger clusters (e.g., margin + alpha * N).
            score = margin - (penalty_coeff * (N - target_N)**2)
            if verbose:
                print(f"Cluster words = {cluster}")
                print(f"Cluster margin = {margin}")
                print(f"Cluster score = {score}")
                print(f"Cluster clue = {nearest_neighbor(centroid, candidate_embs)}")
                print()
            if score > best_score:
                best_score = score
                best_cluster = list(cluster)
                best_N = N
                best_v_star = centroid
        if verbose:
            print()

    # Once the best centroid is chosen, "round" it to a candidate clue word.
    best_clue = nearest_neighbor(best_v_star, candidate_embs)
    if verbose:
        print(f"BEST N: {best_N}")
        print(f"BEST CLUSTER: {best_cluster}")
        print(f"BEST SCORE: {best_score}")
        print(f"BEST CLUE: {best_clue}")
    return best_cluster, best_N, best_v_star, best_clue

# %%
# Initialize the embedding model.
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
print(embedding_model)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
# Re-generate random word and key grids
word_grid, key_grid_player, key_grid_model = generate_grids()
player_word_groups = get_word_groups(word_grid, key_grid_player)
model_word_groups = get_word_groups(word_grid, key_grid_player)

# Separate the friendly words and non-friendlies (bystanders and assassins).
friend_words = player_word_groups['F']
non_friend_words = player_word_groups['B'] + player_word_groups['A']
all_words = friend_words + non_friend_words

# Compute embeddings.
friend_embeddings = {word: embedding_model.encode(word) for word in friend_words}
non_friend_embeddings = {word: embedding_model.encode(word) for word in non_friend_words}
with open('clue_candidates.txt') as f:
    candidate_words = np.array(f.read().splitlines())

# candidate_embeddings = np.array([embedding_model.encode(word) for word in tqdm(candidate_words)])
# np.save("clue_candidate_embeddings.npy", candidate_embeddings)
    
candidate_embeddings = {word:embedding for word, embedding in zip(candidate_words, np.load("clue_candidate_embeddings.npy"))}

candidate_embeddings = filter_dict_by_stemmed_keys(candidate_embeddings, all_words)

# print(json.dumps(player_word_groups, indent=4))
# print()
# print("Friend Words:", friend_words)
# print("Non-Friend Words:", non_friend_words)
# print()
# print(f"Num candidate clues = {len(candidate_embeddings)}")
# print(f"Num candidate clues (filtered) = {len(candidate_embeddings)}")
# print()

best_cluster, best_N, best_v_star, best_clue = \
    find_best_cluster(
        friend_words, 
        non_friend_words, 
        friend_embeddings, 
        non_friend_embeddings, 
        candidate_embeddings,
        target_N=3, 
        penalty_coeff=0.2,
        # verbose=False
    )
# Out:
# N = 1
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH']
# Cluster margin = 0.6298887729644775
# Cluster score = -0.1701112270355225
# Cluster clue = FARMS
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST']
# Cluster margin = 0.6118229627609253
# Cluster score = -0.18817703723907475
# Cluster clue = ATHLETE
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER']
# Cluster margin = 0.5410640239715576
# Cluster score = -0.2589359760284424
# Cluster clue = KNIGHTS
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE']
# Cluster margin = 0.41542887687683105
# Cluster score = -0.384571123123169
# Cluster clue = SECONDS
#
# Cluster seed = "TIN"
# Cluster words = ['TIN']
# Cluster margin = 0.642746090888977
# Cluster score = -0.157253909111023
# Cluster clue = TIFFIN
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE']
# Cluster margin = 0.6192787885665894
# Cluster score = -0.1807212114334107
# Cluster clue = SEAT
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON']
# Cluster margin = 0.6065757870674133
# Cluster score = -0.19342421293258671
# Cluster clue = INFLATED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW']
# Cluster margin = 0.685966968536377
# Cluster score = -0.11403303146362309
# Cluster clue = FOAM
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT']
# Cluster margin = 0.6242108345031738
# Cluster score = -0.17578916549682622
# Cluster clue = BISCAY
#
#
# N = 2
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE']
# Cluster margin = 0.40093958377838135
# Cluster score = 0.20093958377838134
# Cluster clue = HORSEBACK
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE']
# Cluster margin = 0.3248184323310852
# Cluster score = 0.1248184323310852
# Cluster clue = EQUESTRIAN
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH']
# Cluster margin = 0.3172188997268677
# Cluster score = 0.11721889972686766
# Cluster clue = SECT
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST']
# Cluster margin = 0.34226006269454956
# Cluster score = 0.14226006269454955
# Cluster clue = SECONDS
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON']
# Cluster margin = 0.3806804418563843
# Cluster score = 0.18068044185638427
# Cluster clue = TUBE
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW']
# Cluster margin = 0.46135008335113525
# Cluster score = 0.26135008335113524
# Cluster clue = CUSHION
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW']
# Cluster margin = 0.42678165435791016
# Cluster score = 0.22678165435791015
# Cluster clue = INFLATED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE']
# Cluster margin = 0.46135008335113525
# Cluster score = 0.26135008335113524
# Cluster clue = CUSHION
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE']
# Cluster margin = 0.4185935854911804
# Cluster score = 0.2185935854911804
# Cluster clue = BISCAY
#
#
# N = 3
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT']
# Cluster margin = 0.2869139313697815
# Cluster score = 0.2869139313697815
# Cluster clue = HORSEBACK
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW']
# Cluster margin = 0.22137486934661865
# Cluster score = 0.22137486934661865
# Cluster clue = CUSHION
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE']
# Cluster margin = 0.17239677906036377
# Cluster score = 0.17239677906036377
# Cluster clue = HORSEBACK
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE']
# Cluster margin = 0.2086656093597412
# Cluster score = 0.2086656093597412
# Cluster clue = SEAT
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW']
# Cluster margin = 0.2791101932525635
# Cluster score = 0.2791101932525635
# Cluster clue = FOAM
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT']
# Cluster margin = 0.30502864718437195
# Cluster score = 0.30502864718437195
# Cluster clue = CUSHION
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE']
# Cluster margin = 0.25717607140541077
# Cluster score = 0.25717607140541077
# Cluster clue = CUSHION
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT']
# Cluster margin = 0.30502864718437195
# Cluster score = 0.30502864718437195
# Cluster clue = CUSHION
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW']
# Cluster margin = 0.30502867698669434
# Cluster score = 0.30502867698669434
# Cluster clue = CUSHION
#
#
# N = 4
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW']
# Cluster margin = 0.24710234999656677
# Cluster score = 0.04710234999656676
# Cluster clue = CHAUNCY
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON']
# Cluster margin = 0.14889585971832275
# Cluster score = -0.05110414028167726
# Cluster clue = CUSHION
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT']
# Cluster margin = 0.14235782623291016
# Cluster score = -0.057642173767089855
# Cluster clue = BUTCHER
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW']
# Cluster margin = 0.1423393189907074
# Cluster score = -0.057660681009292614
# Cluster clue = SEAT
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE']
# Cluster margin = 0.174271821975708
# Cluster score = -0.025728178024292003
# Cluster clue = FOAM
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH']
# Cluster margin = 0.24710234999656677
# Cluster score = 0.04710234999656676
# Cluster clue = CHAUNCY
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT']
# Cluster margin = 0.1914905607700348
# Cluster score = -0.008509439229965221
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH']
# Cluster margin = 0.24710234999656677
# Cluster score = 0.04710234999656676
# Cluster clue = CHAUNCY
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH']
# Cluster margin = 0.24710234999656677
# Cluster score = 0.04710234999656676
# Cluster clue = CHAUNCY
#
#
# N = 5
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON']
# Cluster margin = 0.11907225847244263
# Cluster score = -0.6809277415275574
# Cluster clue = CHAUNCY
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT']
# Cluster margin = 0.10315823554992676
# Cluster score = -0.6968417644500733
# Cluster clue = CURLED
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT', 'PILLOW']
# Cluster margin = 0.10141444206237793
# Cluster score = -0.6985855579376221
# Cluster clue = DOGGIE
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON']
# Cluster margin = 0.06935769319534302
# Cluster score = -0.730642306804657
# Cluster clue = SEAT
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT']
# Cluster margin = 0.1757740080356598
# Cluster score = -0.6242259919643403
# Cluster clue = CURLED
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH', 'BALLOON']
# Cluster margin = 0.1190723180770874
# Cluster score = -0.6809276819229126
# Cluster clue = CHAUNCY
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'TIN']
# Cluster margin = 0.1757740080356598
# Cluster score = -0.6242259919643403
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH', 'BALLOON']
# Cluster margin = 0.1190723180770874
# Cluster score = -0.6809276819229126
# Cluster clue = CHAUNCY
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH', 'BALLOON']
# Cluster margin = 0.11907225847244263
# Cluster score = -0.6809277415275574
# Cluster clue = CHAUNCY
#
#
# N = 6
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST']
# Cluster margin = 0.05221700668334961
# Cluster score = -1.7477829933166504
# Cluster clue = CHAUNCY
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN']
# Cluster margin = 0.07991686463356018
# Cluster score = -1.7200831353664399
# Cluster clue = CURLED
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON']
# Cluster margin = 0.04888299107551575
# Cluster score = -1.7511170089244843
# Cluster clue = CHAUNCY
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT']
# Cluster margin = 0.036600589752197266
# Cluster score = -1.7633994102478028
# Cluster clue = CURLED
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'GYMNAST']
# Cluster margin = 0.07991683483123779
# Cluster score = -1.7200831651687623
# Cluster clue = CURLED
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST']
# Cluster margin = 0.052216947078704834
# Cluster score = -1.7477830529212952
# Cluster clue = CHAUNCY
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'TIN', 'GYMNAST']
# Cluster margin = 0.07991686463356018
# Cluster score = -1.7200831353664399
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST']
# Cluster margin = 0.052216947078704834
# Cluster score = -1.7477830529212952
# Cluster clue = CHAUNCY
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH', 'BALLOON', 'GYMNAST']
# Cluster margin = 0.052216947078704834
# Cluster score = -1.7477830529212952
# Cluster clue = CHAUNCY
#
#
# N = 7
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST', 'TIN']
# Cluster margin = 0.018096446990966797
# Cluster score = -3.1819035530090334
# Cluster clue = CURLED
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN', 'MINUTE']
# Cluster margin = 0.039448052644729614
# Cluster score = -3.1605519473552706
# Cluster clue = CURLED
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST']
# Cluster margin = -0.021902143955230713
# Cluster score = -3.221902143955231
# Cluster clue = CHAUNCY
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN']
# Cluster margin = 0.039448052644729614
# Cluster score = -3.1605519473552706
# Cluster clue = CURLED
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'GYMNAST', 'MINUTE']
# Cluster margin = 0.039448052644729614
# Cluster score = -3.1605519473552706
# Cluster clue = CURLED
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN']
# Cluster margin = 0.01809638738632202
# Cluster score = -3.181903612613678
# Cluster clue = CURLED
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'TIN', 'GYMNAST', 'MINUTE']
# Cluster margin = 0.03944799304008484
# Cluster score = -3.1605520069599153
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN']
# Cluster margin = 0.01809638738632202
# Cluster score = -3.181903612613678
# Cluster clue = CURLED
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN']
# Cluster margin = 0.01809638738632202
# Cluster score = -3.181903612613678
# Cluster clue = CURLED
#
#
# N = 8
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE']
# Cluster margin = 0.01195448637008667
# Cluster score = -4.988045513629913
# Cluster clue = CURLED
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN', 'MINUTE', 'RANCH']
# Cluster margin = 0.011954456567764282
# Cluster score = -4.988045543432236
# Cluster clue = CURLED
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST', 'TIN']
# Cluster margin = -0.025366365909576416
# Cluster score = -5.025366365909576
# Cluster clue = CURLED
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN', 'RANCH']
# Cluster margin = 0.011954426765441895
# Cluster score = -4.988045573234558
# Cluster clue = CURLED
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'GYMNAST', 'MINUTE', 'RANCH']
# Cluster margin = 0.011954516172409058
# Cluster score = -4.988045483827591
# Cluster clue = CURLED
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE']
# Cluster margin = 0.011954456567764282
# Cluster score = -4.988045543432236
# Cluster clue = CURLED
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'TIN', 'GYMNAST', 'MINUTE', 'RANCH']
# Cluster margin = 0.01195448637008667
# Cluster score = -4.988045513629913
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE']
# Cluster margin = 0.011954456567764282
# Cluster score = -4.988045543432236
# Cluster clue = CURLED
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE']
# Cluster margin = 0.01195448637008667
# Cluster score = -4.988045513629913
# Cluster clue = CURLED
#
#
# N = 9
#
# Cluster seed = "RANCH"
# Cluster words = ['RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "GYMNAST"
# Cluster words = ['GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN', 'MINUTE', 'RANCH', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "CRUSADER"
# Cluster words = ['CRUSADER', 'RANCH', 'SADDLE', 'BISCUIT', 'PILLOW', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "MINUTE"
# Cluster words = ['MINUTE', 'GYMNAST', 'SADDLE', 'PILLOW', 'BALLOON', 'BISCUIT', 'TIN', 'RANCH', 'CRUSADER']
# Cluster margin = -0.026720792055130005
# Cluster score = -7.22672079205513
# Cluster clue = CURLED
#
# Cluster seed = "TIN"
# Cluster words = ['TIN', 'BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'GYMNAST', 'MINUTE', 'RANCH', 'CRUSADER']
# Cluster margin = -0.026720792055130005
# Cluster score = -7.22672079205513
# Cluster clue = CURLED
#
# Cluster seed = "SADDLE"
# Cluster words = ['SADDLE', 'PILLOW', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "BALLOON"
# Cluster words = ['BALLOON', 'PILLOW', 'SADDLE', 'BISCUIT', 'TIN', 'GYMNAST', 'MINUTE', 'RANCH', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "PILLOW"
# Cluster words = ['PILLOW', 'SADDLE', 'BISCUIT', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
# Cluster seed = "BISCUIT"
# Cluster words = ['BISCUIT', 'SADDLE', 'PILLOW', 'RANCH', 'BALLOON', 'GYMNAST', 'TIN', 'MINUTE', 'CRUSADER']
# Cluster margin = -0.026720821857452393
# Cluster score = -7.226720821857453
# Cluster clue = CURLED
#
#
# BEST N: 3
# BEST CLUSTER: ['BISCUIT', 'SADDLE', 'PILLOW']
# BEST SCORE: 0.30502867698669434
# BEST CLUE: CUSHION

# %%
model_word_groups
# Out:
# {'B': ['MESS',
#   'PEANUT',
#   'PACIFIC',
#   'WISH',
#   'LOCUST',
#   'SUN',
#   'SCRATCH',
#   'QUARTER',
#   'LUMBERJACK',
#   'BICYCLE',
#   'SAW',
#   'CAPTAIN',
#   'SWORD'],
#  'F': ['RANCH',
#   'GYMNAST',
#   'CRUSADER',
#   'MINUTE',
#   'TIN',
#   'SADDLE',
#   'BALLOON',
#   'PILLOW',
#   'BISCUIT'],
#  'A': ['STICKER', 'TANK', 'BLIZZARD']}

# %%
generate_clue_sample = {
    "remaining_friendlies": [
        "SECOND",
        "ANTHEM",
        "SMOOTHIE",
        "PARROT",
        "PIZZA",
        "BABY",
        "WIZARD",
        "CHAIN",
        "NERVE"
    ],
    "remaining_bystanders": [
        "BRASS",
        "BRICK",
        "GYMNAST",
        "PADDLE",
        "SOUP",
        "RIVER",
        "GUM",
        "PINE",
        "COFFEE",
        "MUSKETEER",
        "RIFLE",
        "SUGAR",
        "POTTER"
    ],
    "remaining_assassins": [
        "FUEL",
        "DIRECTOR",
        "WONDERLAND"
    ],
    "model_name": "default"
}

generate_guess_sample = {
    "clue_word": "LULLABY",
    "clue_count": 2,
    "remaining_words": [
        'BRASS',
        'FUEL',
        'SECOND',
        'DIRECTOR',
        'ANTHEM',
        'SMOOTHIE',
        'PARROT',
        'BRICK',
        'GYMNAST',
        'PADDLE',
        'SOUP',
        'PIZZA',
        'BABY',
        'WIZARD',
        'RIVER',
        'GUM',
        'PINE',
        'COFFEE',
        'MUSKETEER',
        'WONDERLAND',
        'RIFLE',
        'SUGAR',
        'CHAIN',
        'POTTER',
        'NERVE'
    ],
    "model_name": "default"
}

# %%
print(json.dumps(generate_clue_sample, indent=4))
# Out:
# {
#     "remaining_friendlies": [
#         "SECOND",
#         "ANTHEM",
#         "SMOOTHIE",
#         "PARROT",
#         "PIZZA",
#         "BABY",
#         "WIZARD",
#         "CHAIN",
#         "NERVE"
#     ],
#     "remaining_bystanders": [
#         "BRASS",
#         "BRICK",
#         "GYMNAST",
#         "PADDLE",
#         "SOUP",
#         "RIVER",
#         "GUM",
#         "PINE",
#         "COFFEE",
#         "MUSKETEER",
#         "RIFLE",
#         "SUGAR",
#         "POTTER"
#     ],
#     "remaining_assassins": [
#         "FUEL",
#         "DIRECTOR",
#         "WONDERLAND"
#     ],
#     "model_name": "default"
# }

# %%
print(json.dumps(generate_guess_sample, indent=4))
# Out:
# {
#     "clue_word": "LULLABY",
#     "clue_count": 2,
#     "remaining_words": [
#         "BRASS",
#         "FUEL",
#         "SECOND",
#         "DIRECTOR",
#         "ANTHEM",
#         "SMOOTHIE",
#         "PARROT",
#         "BRICK",
#         "GYMNAST",
#         "PADDLE",
#         "SOUP",
#         "PIZZA",
#         "BABY",
#         "WIZARD",
#         "RIVER",
#         "GUM",
#         "PINE",
#         "COFFEE",
#         "MUSKETEER",
#         "WONDERLAND",
#         "RIFLE",
#         "SUGAR",
#         "CHAIN",
#         "POTTER",
#         "NERVE"
#     ],
#     "model_name": "default"
# }
